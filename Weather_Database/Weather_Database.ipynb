# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
from citipy import citipy
from datetime import datetime
# Import the API key.
from config import g_key
from config import weather_api_key
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 724

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=62e08090379ecb0efa540507e941a4e3'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | dogondoutchi
# Processing Record 5 of Set 1 | bouar
# Processing Record 6 of Set 1 | kajiado
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | uruzgan
# Processing Record 10 of Set 1 | pringsewu
# Processing Record 11 of Set 1 | grindavik
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | port augusta
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 1 | malanville
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | svetlogorsk
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | kropotkin
# Processing Record 27 of Set 1 | richards bay
# Processing Record 28 of Set 1 | vao
# Processing Record 29 of Set 1 | sapele
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | beringovskiy
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | kankavli
# City not found. Skipping...
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | semnan
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 1 | tres arroyos
# Processing Record 45 of Set 1 | varhaug
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | niksar
# Processing Record 48 of Set 1 | inongo
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | umm lajj
# Processing Record 4 of Set 2 | goure
# Processing Record 5 of Set 2 | urengoy
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | cockburn town
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | kaduna
# Processing Record 11 of Set 2 | port hardy
# Processing Record 12 of Set 2 | achacachi
# Processing Record 13 of Set 2 | lasa
# Processing Record 14 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 2 | conceicao do araguaia
# Processing Record 16 of Set 2 | tahe
# Processing Record 17 of Set 2 | katsuura
# Processing Record 18 of Set 2 | kodinsk
# Processing Record 19 of Set 2 | padang
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | yenagoa
# Processing Record 25 of Set 2 | hualmay
# Processing Record 26 of Set 2 | vigeland
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | alice springs
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | mestia
# Processing Record 31 of Set 2 | sibolga
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | bajil
# Processing Record 34 of Set 2 | chemal
# Processing Record 35 of Set 2 | anloga
# Processing Record 36 of Set 2 | hambantota
# Processing Record 37 of Set 2 | margate
# Processing Record 38 of Set 2 | zyryanka
# Processing Record 39 of Set 2 | ambilobe
# Processing Record 40 of Set 2 | saint-denis
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | morehead
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | alugan
# Processing Record 45 of Set 2 | talnakh
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | belmonte
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | puerto carreno
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | pohrebyshche
# Processing Record 6 of Set 3 | zaysan
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | poli
# Processing Record 9 of Set 3 | kieta
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | moron
# Processing Record 12 of Set 3 | chicama
# Processing Record 13 of Set 3 | coquimbo
# Processing Record 14 of Set 3 | wangaratta
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | angoram
# Processing Record 17 of Set 3 | werda
# Processing Record 18 of Set 3 | rorvik
# Processing Record 19 of Set 3 | ovsyanka
# Processing Record 20 of Set 3 | carutapera
# Processing Record 21 of Set 3 | takoradi
# Processing Record 22 of Set 3 | ixtapa
# Processing Record 23 of Set 3 | lar gerd
# City not found. Skipping...
# Processing Record 24 of Set 3 | sorong
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | belle glade
# Processing Record 28 of Set 3 | drayton valley
# Processing Record 29 of Set 3 | marystown
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | kununurra
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | bredasdorp
# Processing Record 36 of Set 3 | partizanskoye
# Processing Record 37 of Set 3 | jacareacanga
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | nabire
# Processing Record 40 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 3 | altamira
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | te anau
# Processing Record 45 of Set 3 | soyo
# Processing Record 46 of Set 3 | agadez
# Processing Record 47 of Set 3 | hami
# Processing Record 48 of Set 3 | cuenca
# Processing Record 49 of Set 3 | abu samrah
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | clarksburg
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | taoudenni
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | piacabucu
# Processing Record 6 of Set 4 | canchungo
# Processing Record 7 of Set 4 | stuttgart
# Processing Record 8 of Set 4 | mecca
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | namatanai
# Processing Record 11 of Set 4 | alofi
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 4 | mahibadhoo
# Processing Record 15 of Set 4 | sandy bay
# Processing Record 16 of Set 4 | sitka
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | ushibuka
# Processing Record 20 of Set 4 | umm kaddadah
# Processing Record 21 of Set 4 | pisco
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | brigham city
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | nizhneangarsk
# Processing Record 27 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 4 | poum
# Processing Record 29 of Set 4 | lakes entrance
# Processing Record 30 of Set 4 | davidson
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | nattam
# Processing Record 33 of Set 4 | fort nelson
# Processing Record 34 of Set 4 | camacha
# Processing Record 35 of Set 4 | riverton
# Processing Record 36 of Set 4 | maumere
# Processing Record 37 of Set 4 | olinda
# Processing Record 38 of Set 4 | emba
# Processing Record 39 of Set 4 | yumen
# Processing Record 40 of Set 4 | pauri
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | huarmey
# Processing Record 43 of Set 4 | oktyabrskoye
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | longyearbyen
# Processing Record 47 of Set 4 | suntar
# Processing Record 48 of Set 4 | rawson
# Processing Record 49 of Set 4 | koumac
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | kultuk
# Processing Record 2 of Set 5 | palmas
# Processing Record 3 of Set 5 | mayor pablo lagerenza
# Processing Record 4 of Set 5 | yichang
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | cap malheureux
# Processing Record 7 of Set 5 | kapoeta
# Processing Record 8 of Set 5 | sola
# Processing Record 9 of Set 5 | natal
# Processing Record 10 of Set 5 | imeni babushkina
# Processing Record 11 of Set 5 | naukot
# Processing Record 12 of Set 5 | rakhya
# City not found. Skipping...
# Processing Record 13 of Set 5 | sao miguel do araguaia
# Processing Record 14 of Set 5 | lavrentiya
# Processing Record 15 of Set 5 | plettenberg bay
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | boddam
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | erzin
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | bodden town
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | siilinjarvi
# Processing Record 24 of Set 5 | killybegs
# Processing Record 25 of Set 5 | caravelas
# Processing Record 26 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 27 of Set 5 | thinadhoo
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | baculin
# Processing Record 30 of Set 5 | saint-joseph
# Processing Record 31 of Set 5 | praia da vitoria
# Processing Record 32 of Set 5 | marfino
# Processing Record 33 of Set 5 | cabedelo
# Processing Record 34 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 5 | brae
# Processing Record 36 of Set 5 | jinchang
# Processing Record 37 of Set 5 | san patricio
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | bethel
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | hays
# Processing Record 42 of Set 5 | berlevag
# Processing Record 43 of Set 5 | dunedin
# Processing Record 44 of Set 5 | borzya
# Processing Record 45 of Set 5 | balrampur
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 5 | college
# Processing Record 50 of Set 5 | tacuarembo
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | tuktoyaktuk
# Processing Record 5 of Set 6 | buin
# Processing Record 6 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 6 | satun
# Processing Record 8 of Set 6 | kaitangata
# Processing Record 9 of Set 6 | ostrovnoy
# Processing Record 10 of Set 6 | taman
# Processing Record 11 of Set 6 | grunberg
# Processing Record 12 of Set 6 | porto novo
# Processing Record 13 of Set 6 | ndele
# Processing Record 14 of Set 6 | suez
# Processing Record 15 of Set 6 | san rafael
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | ambagarh chauki
# Processing Record 18 of Set 6 | rocha
# Processing Record 19 of Set 6 | sabha
# Processing Record 20 of Set 6 | along
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | kodiak
# Processing Record 23 of Set 6 | sao felix do xingu
# Processing Record 24 of Set 6 | kasamwa
# Processing Record 25 of Set 6 | esmeraldas
# Processing Record 26 of Set 6 | new guinlo
# City not found. Skipping...
# Processing Record 27 of Set 6 | tuatapere
# Processing Record 28 of Set 6 | verkhoyansk
# Processing Record 29 of Set 6 | mattru
# Processing Record 30 of Set 6 | durban
# Processing Record 31 of Set 6 | sinop
# Processing Record 32 of Set 6 | casablanca
# Processing Record 33 of Set 6 | hithadhoo
# Processing Record 34 of Set 6 | north bend
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | bambanglipuro
# Processing Record 37 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 6 | korla
# Processing Record 39 of Set 6 | bilma
# Processing Record 40 of Set 6 | zacatepec
# Processing Record 41 of Set 6 | cayenne
# Processing Record 42 of Set 6 | port moresby
# Processing Record 43 of Set 6 | kautokeino
# Processing Record 44 of Set 6 | saint-francois
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | tiznit
# Processing Record 47 of Set 6 | pozo colorado
# Processing Record 48 of Set 6 | mackay
# Processing Record 49 of Set 6 | maple creek
# Processing Record 50 of Set 6 | clyde river
# Processing Record 1 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 2 of Set 7 | saint-georges
# Processing Record 3 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 4 of Set 7 | yarada
# Processing Record 5 of Set 7 | nikolskoye
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | karratha
# Processing Record 8 of Set 7 | tessalit
# Processing Record 9 of Set 7 | havoysund
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | boralday
# Processing Record 12 of Set 7 | warmbad
# Processing Record 13 of Set 7 | weymouth
# Processing Record 14 of Set 7 | jos
# Processing Record 15 of Set 7 | alta floresta
# Processing Record 16 of Set 7 | bay roberts
# Processing Record 17 of Set 7 | lethem
# Processing Record 18 of Set 7 | stromness
# Processing Record 19 of Set 7 | lata
# Processing Record 20 of Set 7 | xuanwu
# Processing Record 21 of Set 7 | kutum
# Processing Record 22 of Set 7 | ojinaga
# Processing Record 23 of Set 7 | orzesze
# Processing Record 24 of Set 7 | green river
# Processing Record 25 of Set 7 | yongan
# Processing Record 26 of Set 7 | bairnsdale
# Processing Record 27 of Set 7 | innisfail
# Processing Record 28 of Set 7 | bhimunipatnam
# Processing Record 29 of Set 7 | kristiinankaupunki
# Processing Record 30 of Set 7 | sao joao da barra
# Processing Record 31 of Set 7 | port elizabeth
# Processing Record 32 of Set 7 | novyy urengoy
# Processing Record 33 of Set 7 | arkhangelsk
# Processing Record 34 of Set 7 | fare
# Processing Record 35 of Set 7 | komsomolskiy
# Processing Record 36 of Set 7 | gat
# Processing Record 37 of Set 7 | lewiston
# Processing Record 38 of Set 7 | morant bay
# Processing Record 39 of Set 7 | oranjemund
# Processing Record 40 of Set 7 | mitsamiouli
# Processing Record 41 of Set 7 | miles city
# Processing Record 42 of Set 7 | deputatskiy
# Processing Record 43 of Set 7 | puerto del rosario
# Processing Record 44 of Set 7 | puerto escondido
# Processing Record 45 of Set 7 | la romana
# Processing Record 46 of Set 7 | chapleau
# Processing Record 47 of Set 7 | baruun-urt
# Processing Record 48 of Set 7 | bell ville
# Processing Record 49 of Set 7 | mount gambier
# Processing Record 50 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 8 | georgetown
# Processing Record 2 of Set 8 | ankang
# Processing Record 3 of Set 8 | isangel
# Processing Record 4 of Set 8 | sivas
# Processing Record 5 of Set 8 | kilimatinde
# Processing Record 6 of Set 8 | tutoia
# Processing Record 7 of Set 8 | simao
# Processing Record 8 of Set 8 | narsaq
# Processing Record 9 of Set 8 | kendari
# Processing Record 10 of Set 8 | usinsk
# Processing Record 11 of Set 8 | tabas
# Processing Record 12 of Set 8 | culpeper
# Processing Record 13 of Set 8 | cap-aux-meules
# Processing Record 14 of Set 8 | dudinka
# Processing Record 15 of Set 8 | atar
# Processing Record 16 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 17 of Set 8 | honiara
# Processing Record 18 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 8 | decatur
# Processing Record 20 of Set 8 | vitimskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | indianola
# Processing Record 22 of Set 8 | lere
# Processing Record 23 of Set 8 | huejuquilla el alto
# Processing Record 24 of Set 8 | maragogi
# Processing Record 25 of Set 8 | lac du bonnet
# Processing Record 26 of Set 8 | taree
# Processing Record 27 of Set 8 | matay
# Processing Record 28 of Set 8 | cuicatlan
# Processing Record 29 of Set 8 | victoria
# Processing Record 30 of Set 8 | moree
# Processing Record 31 of Set 8 | dali
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | gummidipundi
# Processing Record 34 of Set 8 | avera
# Processing Record 35 of Set 8 | acapulco
# Processing Record 36 of Set 8 | reconquista
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | kruisfontein
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | severodvinsk
# Processing Record 41 of Set 8 | comodoro rivadavia
# Processing Record 42 of Set 8 | axim
# Processing Record 43 of Set 8 | nuuk
# Processing Record 44 of Set 8 | forbes
# Processing Record 45 of Set 8 | ayagoz
# Processing Record 46 of Set 8 | the valley
# Processing Record 47 of Set 8 | zhangye
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | poya
# Processing Record 50 of Set 8 | wiang sa
# Processing Record 1 of Set 9 | namibe
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | bredy
# Processing Record 4 of Set 9 | tual
# Processing Record 5 of Set 9 | imbituba
# Processing Record 6 of Set 9 | westport
# Processing Record 7 of Set 9 | tomatlan
# Processing Record 8 of Set 9 | kiunga
# Processing Record 9 of Set 9 | newberry
# Processing Record 10 of Set 9 | bulawayo
# Processing Record 11 of Set 9 | lunenburg
# Processing Record 12 of Set 9 | cherskiy
# Processing Record 13 of Set 9 | pineville
# Processing Record 14 of Set 9 | jaguaribe
# Processing Record 15 of Set 9 | sorland
# Processing Record 16 of Set 9 | ikoma
# Processing Record 17 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 9 | dickinson
# Processing Record 19 of Set 9 | port lincoln
# Processing Record 20 of Set 9 | safford
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | manaure
# Processing Record 23 of Set 9 | ullal
# Processing Record 24 of Set 9 | hovd
# Processing Record 25 of Set 9 | sunndalsora
# Processing Record 26 of Set 9 | vanavara
# Processing Record 27 of Set 9 | esil
# Processing Record 28 of Set 9 | stephenville
# Processing Record 29 of Set 9 | bonfim
# Processing Record 30 of Set 9 | fortuna
# Processing Record 31 of Set 9 | mercedes
# Processing Record 32 of Set 9 | novo aripuana
# Processing Record 33 of Set 9 | walla walla
# Processing Record 34 of Set 9 | tlapehuala
# Processing Record 35 of Set 9 | ahipara
# Processing Record 36 of Set 9 | dhidhdhoo
# Processing Record 37 of Set 9 | egvekinot
# Processing Record 38 of Set 9 | coahuayana
# Processing Record 39 of Set 9 | sokolovskoye
# Processing Record 40 of Set 9 | walvis bay
# Processing Record 41 of Set 9 | guerrero negro
# Processing Record 42 of Set 9 | opuwo
# Processing Record 43 of Set 9 | melfi
# Processing Record 44 of Set 9 | souris
# Processing Record 45 of Set 9 | ouadda
# Processing Record 46 of Set 9 | thohoyandou
# Processing Record 47 of Set 9 | san fernando
# Processing Record 48 of Set 9 | katsina
# Processing Record 49 of Set 9 | abu kamal
# Processing Record 50 of Set 9 | okhotsk
# Processing Record 1 of Set 10 | vila velha
# Processing Record 2 of Set 10 | wagga wagga
# Processing Record 3 of Set 10 | gasa
# Processing Record 4 of Set 10 | nemuro
# Processing Record 5 of Set 10 | khandyga
# Processing Record 6 of Set 10 | udachnyy
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | malindi
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | manado
# Processing Record 11 of Set 10 | la troncal
# Processing Record 12 of Set 10 | faya
# Processing Record 13 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 14 of Set 10 | caldas novas
# Processing Record 15 of Set 10 | guymon
# Processing Record 16 of Set 10 | north platte
# Processing Record 17 of Set 10 | champoton
# Processing Record 18 of Set 10 | worland
# Processing Record 19 of Set 10 | asau
# Processing Record 20 of Set 10 | fairbanks
# Processing Record 21 of Set 10 | nazira
# Processing Record 22 of Set 10 | roald
# Processing Record 23 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 10 | biak
# Processing Record 25 of Set 10 | muhos
# Processing Record 26 of Set 10 | alyangula
# Processing Record 27 of Set 10 | mpongwe
# Processing Record 28 of Set 10 | tuy hoa
# Processing Record 29 of Set 10 | buala
# Processing Record 30 of Set 10 | henties bay
# Processing Record 31 of Set 10 | luena
# Processing Record 32 of Set 10 | ziro
# Processing Record 33 of Set 10 | rajpipla
# Processing Record 34 of Set 10 | kurilsk
# Processing Record 35 of Set 10 | tilichiki
# Processing Record 36 of Set 10 | baniyas
# Processing Record 37 of Set 10 | borovskoy
# Processing Record 38 of Set 10 | zinder
# Processing Record 39 of Set 10 | carballo
# Processing Record 40 of Set 10 | jishu
# Processing Record 41 of Set 10 | jiwani
# Processing Record 42 of Set 10 | arlit
# Processing Record 43 of Set 10 | nizwa
# Processing Record 44 of Set 10 | la paz
# Processing Record 45 of Set 10 | pacific grove
# Processing Record 46 of Set 10 | ingham
# Processing Record 47 of Set 10 | neuquen
# Processing Record 48 of Set 10 | quezon
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | raymondville
# Processing Record 1 of Set 11 | srednekolymsk
# Processing Record 2 of Set 11 | russell
# Processing Record 3 of Set 11 | sangar
# Processing Record 4 of Set 11 | nosy varika
# Processing Record 5 of Set 11 | pontes e lacerda
# Processing Record 6 of Set 11 | xalpatlahuac
# Processing Record 7 of Set 11 | porto walter
# Processing Record 8 of Set 11 | kloulklubed
# Processing Record 9 of Set 11 | that phanom
# Processing Record 10 of Set 11 | tinaquillo
# Processing Record 11 of Set 11 | zonguldak
# Processing Record 12 of Set 11 | tupik
# Processing Record 13 of Set 11 | leh
# Processing Record 14 of Set 11 | burnie
# Processing Record 15 of Set 11 | suifenhe
# Processing Record 16 of Set 11 | san andres
# Processing Record 17 of Set 11 | kargapolye
# City not found. Skipping...
# Processing Record 18 of Set 11 | road town
# Processing Record 19 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 20 of Set 11 | chokurdakh
# Processing Record 21 of Set 11 | bonthe
# Processing Record 22 of Set 11 | dedza
# Processing Record 23 of Set 11 | menongue
# Processing Record 24 of Set 11 | sam roi yot
# Processing Record 25 of Set 11 | satipo
# Processing Record 26 of Set 11 | castanos
# Processing Record 27 of Set 11 | ambulu
# Processing Record 28 of Set 11 | washougal
# Processing Record 29 of Set 11 | vestmannaeyjar
# Processing Record 30 of Set 11 | songea
# Processing Record 31 of Set 11 | pangody
# Processing Record 32 of Set 11 | surt
# Processing Record 33 of Set 11 | tahta
# Processing Record 34 of Set 11 | guangshui
# Processing Record 35 of Set 11 | birjand
# Processing Record 36 of Set 11 | jamame
# Processing Record 37 of Set 11 | mozelos
# Processing Record 38 of Set 11 | manono
# Processing Record 39 of Set 11 | paripiranga
# Processing Record 40 of Set 11 | crossville
# Processing Record 41 of Set 11 | adelaide
# Processing Record 42 of Set 11 | saint-pierre
# Processing Record 43 of Set 11 | hofn
# Processing Record 44 of Set 11 | salinopolis
# Processing Record 45 of Set 11 | bowen
# Processing Record 46 of Set 11 | bandarbeyla
# Processing Record 47 of Set 11 | pimentel
# Processing Record 48 of Set 11 | brooks
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | zhigalovo
# Processing Record 1 of Set 12 | sarh
# Processing Record 2 of Set 12 | gravdal
# Processing Record 3 of Set 12 | khor
# Processing Record 4 of Set 12 | gayny
# Processing Record 5 of Set 12 | cacapava do sul
# Processing Record 6 of Set 12 | ugoofaaru
# Processing Record 7 of Set 12 | agirish
# Processing Record 8 of Set 12 | nijar
# Processing Record 9 of Set 12 | ithaca
# Processing Record 10 of Set 12 | churapcha
# Processing Record 11 of Set 12 | arrifes
# Processing Record 12 of Set 12 | hauterive
# Processing Record 13 of Set 12 | coracao de jesus
# Processing Record 14 of Set 12 | conceicao da barra
# Processing Record 15 of Set 12 | chabahar
# Processing Record 16 of Set 12 | salinas
# Processing Record 17 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 12 | kungurtug
# Processing Record 19 of Set 12 | fallon
# Processing Record 20 of Set 12 | boyolangu
# Processing Record 21 of Set 12 | kupang
# Processing Record 22 of Set 12 | tautira
# Processing Record 23 of Set 12 | krasnogorodsk
# Processing Record 24 of Set 12 | nouakchott
# Processing Record 25 of Set 12 | phalaborwa
# Processing Record 26 of Set 12 | kaeo
# Processing Record 27 of Set 12 | boguchany
# Processing Record 28 of Set 12 | port-gentil
# Processing Record 29 of Set 12 | mayo
# Processing Record 30 of Set 12 | santo tomas
# Processing Record 31 of Set 12 | husavik
# Processing Record 32 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 12 | amapa
# Processing Record 34 of Set 12 | flinders
# Processing Record 35 of Set 12 | kismayo
# Processing Record 36 of Set 12 | vieux fort
# Processing Record 37 of Set 12 | nhulunbuy
# Processing Record 38 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 12 | itaituba
# Processing Record 40 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 12 | vanimo
# Processing Record 42 of Set 12 | gao
# Processing Record 43 of Set 12 | labuhan
# Processing Record 44 of Set 12 | hailey
# Processing Record 45 of Set 12 | jimenez
# Processing Record 46 of Set 12 | tsumeb
# Processing Record 47 of Set 12 | mnogovershinnyy
# Processing Record 48 of Set 12 | poronaysk
# Processing Record 49 of Set 12 | tingi
# Processing Record 50 of Set 12 | havelock
# Processing Record 1 of Set 13 | gloversville
# Processing Record 2 of Set 13 | mount isa
# Processing Record 3 of Set 13 | tevriz
# Processing Record 4 of Set 13 | rognan
# Processing Record 5 of Set 13 | camopi
# Processing Record 6 of Set 13 | asbe teferi
# Processing Record 7 of Set 13 | camara de lobos
# Processing Record 8 of Set 13 | maceio
# Processing Record 9 of Set 13 | kalevala
# Processing Record 10 of Set 13 | chara
# Processing Record 11 of Set 13 | dhing
# Processing Record 12 of Set 13 | saint-michel-des-saints
# Processing Record 13 of Set 13 | heidelberg
# Processing Record 14 of Set 13 | batemans bay
# Processing Record 15 of Set 13 | port antonio
# Processing Record 16 of Set 13 | ippy
# Processing Record 17 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 13 | batagay
# Processing Record 19 of Set 13 | kuusamo
# Processing Record 20 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 13 | vanderhoof
# Processing Record 22 of Set 13 | araouane
# Processing Record 23 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 24 of Set 13 | jepara
# Processing Record 25 of Set 13 | meulaboh
# Processing Record 26 of Set 13 | nelson bay
# Processing Record 27 of Set 13 | bella union
# Processing Record 28 of Set 13 | zalantun
# Processing Record 29 of Set 13 | prince rupert
# Processing Record 30 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 13 | shimoda
# Processing Record 32 of Set 13 | tazovskiy
# Processing Record 33 of Set 13 | tremedal
# Processing Record 34 of Set 13 | dois corregos
# Processing Record 35 of Set 13 | kulhudhuffushi
# Processing Record 36 of Set 13 | xuddur
# Processing Record 37 of Set 13 | leningradskiy
# Processing Record 38 of Set 13 | masvingo
# Processing Record 39 of Set 13 | sinnamary
# Processing Record 40 of Set 13 | paamiut
# Processing Record 41 of Set 13 | chilca
# Processing Record 42 of Set 13 | minab
# Processing Record 43 of Set 13 | tera
# Processing Record 44 of Set 13 | kanniyakumari
# Processing Record 45 of Set 13 | pierre
# Processing Record 46 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 13 | high prairie
# Processing Record 48 of Set 13 | nome
# Processing Record 49 of Set 13 | ngunguru
# Processing Record 50 of Set 13 | noumea
# Processing Record 1 of Set 14 | tinskoy
# Processing Record 2 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 14 | bhadrak
# Processing Record 4 of Set 14 | antofagasta
# Processing Record 5 of Set 14 | xiaoweizhai
# Processing Record 6 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 7 of Set 14 | anamur
# Processing Record 8 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | chabua
# Processing Record 10 of Set 14 | bubaque
# Processing Record 11 of Set 14 | nouadhibou
# Processing Record 12 of Set 14 | mexico
# Processing Record 13 of Set 14 | sur
# Processing Record 14 of Set 14 | thurso
# Processing Record 15 of Set 14 | bonavista
# Processing Record 16 of Set 14 | iquique
# Processing Record 17 of Set 14 | yaan
# Processing Record 18 of Set 14 | arvika
# Processing Record 19 of Set 14 | iralaya
# Processing Record 20 of Set 14 | hemnesberget
# Processing Record 21 of Set 14 | kenora
# Processing Record 22 of Set 14 | portland
# Processing Record 23 of Set 14 | long xuyen
# Processing Record 24 of Set 14 | khash
# Processing Record 25 of Set 14 | odweyne
# Processing Record 26 of Set 14 | kaset sombun
# Processing Record 27 of Set 14 | antakya
# Processing Record 28 of Set 14 | mehamn
# Processing Record 29 of Set 14 | mixtequilla
# City not found. Skipping...
# Processing Record 30 of Set 14 | tsaratanana
# Processing Record 31 of Set 14 | ayr
# Processing Record 32 of Set 14 | lagoa
# Processing Record 33 of Set 14 | calbuco
# Processing Record 34 of Set 14 | puerto colombia
# Processing Record 35 of Set 14 | maridi
# Processing Record 36 of Set 14 | port-cartier
# Processing Record 37 of Set 14 | duobao
# Processing Record 38 of Set 14 | tura
# Processing Record 39 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 14 | tulsipur
# Processing Record 41 of Set 14 | victor harbor
# Processing Record 42 of Set 14 | mina
# Processing Record 43 of Set 14 | berdigestyakh
# Processing Record 44 of Set 14 | saint-andre-avellin
# Processing Record 45 of Set 14 | beyneu
# Processing Record 46 of Set 14 | barcelona
# Processing Record 47 of Set 14 | santiago
# Processing Record 48 of Set 14 | atbasar
# Processing Record 49 of Set 14 | siderno
# Processing Record 50 of Set 14 | solnechnyy
# Processing Record 1 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 2 of Set 15 | rexburg
# Processing Record 3 of Set 15 | yar-sale
# Processing Record 4 of Set 15 | gizo
# Processing Record 5 of Set 15 | astoria
# Processing Record 6 of Set 15 | novopavlovka
# Processing Record 7 of Set 15 | denia
# Processing Record 8 of Set 15 | bardiyah
# Processing Record 9 of Set 15 | boda
# Processing Record 10 of Set 15 | ust-kuyga
# Processing Record 11 of Set 15 | elesbao veloso
# Processing Record 12 of Set 15 | benicarlo
# Processing Record 13 of Set 15 | mobaye
# Processing Record 14 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 15 | ruteng
# Processing Record 16 of Set 15 | oriximina
# Processing Record 17 of Set 15 | simbahan
# Processing Record 18 of Set 15 | naze
# Processing Record 19 of Set 15 | mastic beach
# Processing Record 20 of Set 15 | roebourne
# Processing Record 21 of Set 15 | owensboro
# Processing Record 22 of Set 15 | qasigiannguit
# Processing Record 23 of Set 15 | novyy khushet
# Processing Record 24 of Set 15 | normandin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Provideniya  64.3833 -173.3000     43.34        81         100
# 1     Busselton -33.6500  115.3333     54.09        75         100
# 2  Dogondoutchi  13.6393    4.0287     93.29        38          79
# 3         Bouar   5.9340   15.5960     65.97        93         100
# 4       Kajiado  -1.8524   36.7768     66.92        73           1
# 5        Avarua -21.2078 -159.7750     73.45        94          20
# 6       Qaanaaq  77.4840  -69.3632     45.14        65          62
# 7       Uruzgan  32.8333   66.0000     75.56        19           1
# 8     Pringsewu  -5.3582  104.9744     73.60        98          80
# 9     Grindavik  63.8424  -22.4338     51.96        98         100
#
#    Wind Speed Current Description
# 0        2.13     overcast clouds
# 1       20.56     overcast clouds
# 2        4.18       broken clouds
# 3        1.97     overcast clouds
# 4       10.71           clear sky
# 5        4.61          few clouds
# 6        1.97       broken clouds
# 7        1.83           clear sky
# 8        3.15       broken clouds
# 9       18.03     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
