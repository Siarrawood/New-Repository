# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
from citipy import citipy
from datetime import datetime
# Import the API key.
from config import g_key
from config import weather_api_key
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=62e08090379ecb0efa540507e941a4e3'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | lavrentiya
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | vermilion
# Processing Record 5 of Set 1 | lasa
# Processing Record 6 of Set 1 | kolaras
# Processing Record 7 of Set 1 | paamiut
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | adrar
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | yantai
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | eskisehir
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | faya
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | sayyan
# Processing Record 26 of Set 1 | dandong
# Processing Record 27 of Set 1 | batticaloa
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | talnakh
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | diego de almagro
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | providencia
# Processing Record 36 of Set 1 | srednekolymsk
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | delmiro gouveia
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | weihe
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | biloela
# Processing Record 46 of Set 1 | garoua boulai
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | blythe
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | asahi
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | los llanos de aridane
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | iskateley
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | luanda
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | bambanglipuro
# Processing Record 12 of Set 2 | kikwit
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | margate
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | fairbanks
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | samarai
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | hamilton
# Processing Record 21 of Set 2 | santa fe
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | hokitika
# Processing Record 24 of Set 2 | buayan
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | bagotville
# Processing Record 27 of Set 2 | constitucion
# Processing Record 28 of Set 2 | mezen
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | belyy yar
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 2 | verkhoyansk
# Processing Record 34 of Set 2 | boma
# Processing Record 35 of Set 2 | mayo
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | nicoya
# Processing Record 39 of Set 2 | dingle
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | dukat
# Processing Record 44 of Set 2 | sabang
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | mehamn
# Processing Record 47 of Set 2 | guerrero negro
# Processing Record 48 of Set 2 | kovdor
# Processing Record 49 of Set 2 | lake city
# Processing Record 50 of Set 2 | kristiansand
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | colomi
# Processing Record 3 of Set 3 | lebedinyy
# Processing Record 4 of Set 3 | akonolinga
# Processing Record 5 of Set 3 | raga
# Processing Record 6 of Set 3 | imisli
# City not found. Skipping...
# Processing Record 7 of Set 3 | pasinler
# Processing Record 8 of Set 3 | avera
# Processing Record 9 of Set 3 | anchorage
# Processing Record 10 of Set 3 | ahipara
# Processing Record 11 of Set 3 | palu
# Processing Record 12 of Set 3 | vao
# Processing Record 13 of Set 3 | nelson bay
# Processing Record 14 of Set 3 | general roca
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | shimoda
# Processing Record 17 of Set 3 | makung
# City not found. Skipping...
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | port-gentil
# Processing Record 20 of Set 3 | abu dhabi
# Processing Record 21 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | kapustin yar
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | westport
# Processing Record 26 of Set 3 | santa maria
# Processing Record 27 of Set 3 | poyarkovo
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | qui nhon
# Processing Record 30 of Set 3 | port hedland
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | krasnoselkup
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | puerto rico
# Processing Record 36 of Set 3 | coquimbo
# Processing Record 37 of Set 3 | meulaboh
# Processing Record 38 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 3 | necochea
# Processing Record 40 of Set 3 | caravelas
# Processing Record 41 of Set 3 | huilong
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 3 | annau
# Processing Record 45 of Set 3 | riyadh
# Processing Record 46 of Set 3 | kutum
# Processing Record 47 of Set 3 | pionerskiy
# Processing Record 48 of Set 3 | autazes
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | port blair
# Processing Record 1 of Set 4 | poum
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | skibbereen
# Processing Record 4 of Set 4 | suruc
# Processing Record 5 of Set 4 | buala
# Processing Record 6 of Set 4 | goranboy
# Processing Record 7 of Set 4 | hovd
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | luena
# Processing Record 10 of Set 4 | mocuba
# Processing Record 11 of Set 4 | cartagena
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | rio grande
# Processing Record 14 of Set 4 | shadegan
# Processing Record 15 of Set 4 | lokosovo
# Processing Record 16 of Set 4 | hobyo
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | tukrah
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | leh
# Processing Record 22 of Set 4 | nakusp
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | sungaipenuh
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | ndele
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | divnomorskoye
# Processing Record 29 of Set 4 | marsa matruh
# Processing Record 30 of Set 4 | chauk
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | cockburn town
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | kamaishi
# Processing Record 37 of Set 4 | palmares do sul
# Processing Record 38 of Set 4 | robe
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | yulara
# Processing Record 41 of Set 4 | ano mera
# Processing Record 42 of Set 4 | san vicente
# Processing Record 43 of Set 4 | ban dung
# Processing Record 44 of Set 4 | tolmezzo
# Processing Record 45 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | preobrazheniye
# Processing Record 47 of Set 4 | dicabisagan
# Processing Record 48 of Set 4 | ambon
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | hithadhoo
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 5 | urumqi
# Processing Record 4 of Set 5 | natal
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 5 | huangpi
# Processing Record 8 of Set 5 | west wendover
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 5 | sao jose da coroa grande
# Processing Record 12 of Set 5 | teya
# Processing Record 13 of Set 5 | sao miguel do araguaia
# Processing Record 14 of Set 5 | lebu
# Processing Record 15 of Set 5 | broome
# Processing Record 16 of Set 5 | mersing
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 5 | port lincoln
# Processing Record 20 of Set 5 | jacareacanga
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | rylsk
# Processing Record 23 of Set 5 | fuling
# Processing Record 24 of Set 5 | muzhi
# Processing Record 25 of Set 5 | bhawana
# Processing Record 26 of Set 5 | yeppoon
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | fortuna
# Processing Record 29 of Set 5 | baijiantan
# Processing Record 30 of Set 5 | sola
# Processing Record 31 of Set 5 | lorengau
# Processing Record 32 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 33 of Set 5 | zyryanka
# Processing Record 34 of Set 5 | newport
# Processing Record 35 of Set 5 | sibolga
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | deputatskiy
# Processing Record 38 of Set 5 | college
# Processing Record 39 of Set 5 | deniliquin
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | toyooka
# Processing Record 42 of Set 5 | tongren
# Processing Record 43 of Set 5 | molina
# Processing Record 44 of Set 5 | egvekinot
# Processing Record 45 of Set 5 | torbay
# Processing Record 46 of Set 5 | kaabong
# Processing Record 47 of Set 5 | olga
# Processing Record 48 of Set 5 | lazaro cardenas
# Processing Record 49 of Set 5 | abancay
# Processing Record 50 of Set 5 | kitovo
# Processing Record 1 of Set 6 | sao joao da barra
# Processing Record 2 of Set 6 | hualmay
# Processing Record 3 of Set 6 | haines junction
# Processing Record 4 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 6 | praia da vitoria
# Processing Record 6 of Set 6 | launceston
# Processing Record 7 of Set 6 | cabo san lucas
# Processing Record 8 of Set 6 | peleduy
# Processing Record 9 of Set 6 | oudtshoorn
# Processing Record 10 of Set 6 | priiskovyy
# Processing Record 11 of Set 6 | redlands
# Processing Record 12 of Set 6 | nisia floresta
# Processing Record 13 of Set 6 | mareeba
# Processing Record 14 of Set 6 | litovko
# Processing Record 15 of Set 6 | hambantota
# Processing Record 16 of Set 6 | gorontalo
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | manokwari
# Processing Record 19 of Set 6 | zhigansk
# Processing Record 20 of Set 6 | alekseyevka
# Processing Record 21 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 6 | castro
# Processing Record 23 of Set 6 | hov
# Processing Record 24 of Set 6 | raymond
# Processing Record 25 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 6 | tilichiki
# Processing Record 27 of Set 6 | labuhan
# Processing Record 28 of Set 6 | mende
# Processing Record 29 of Set 6 | san quintin
# Processing Record 30 of Set 6 | port moresby
# Processing Record 31 of Set 6 | khani
# Processing Record 32 of Set 6 | fort nelson
# Processing Record 33 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 34 of Set 6 | lisakovsk
# Processing Record 35 of Set 6 | saint-pierre
# Processing Record 36 of Set 6 | taloqan
# Processing Record 37 of Set 6 | avarua
# Processing Record 38 of Set 6 | paz de ariporo
# City not found. Skipping...
# Processing Record 39 of Set 6 | leningradskiy
# Processing Record 40 of Set 6 | muros
# Processing Record 41 of Set 6 | makakilo city
# Processing Record 42 of Set 6 | tombouctou
# Processing Record 43 of Set 6 | rio gallegos
# Processing Record 44 of Set 6 | katherine
# Processing Record 45 of Set 6 | maracacume
# Processing Record 46 of Set 6 | ladario
# Processing Record 47 of Set 6 | rawson
# Processing Record 48 of Set 6 | mahebourg
# Processing Record 49 of Set 6 | dombarovskiy
# Processing Record 50 of Set 6 | sanming
# Processing Record 1 of Set 7 | cap malheureux
# Processing Record 2 of Set 7 | provideniya
# Processing Record 3 of Set 7 | neiafu
# Processing Record 4 of Set 7 | san ramon
# Processing Record 5 of Set 7 | ucluelet
# Processing Record 6 of Set 7 | abu samrah
# Processing Record 7 of Set 7 | alice springs
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | heishan
# Processing Record 10 of Set 7 | devanhalli
# Processing Record 11 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 13 of Set 7 | kinshasa
# Processing Record 14 of Set 7 | obluche
# City not found. Skipping...
# Processing Record 15 of Set 7 | polson
# Processing Record 16 of Set 7 | khandagayty
# Processing Record 17 of Set 7 | kinsale
# Processing Record 18 of Set 7 | bengkulu
# Processing Record 19 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | mackenzie
# Processing Record 22 of Set 7 | sandpoint
# Processing Record 23 of Set 7 | kamenka
# Processing Record 24 of Set 7 | vardo
# Processing Record 25 of Set 7 | matias romero
# Processing Record 26 of Set 7 | bilma
# Processing Record 27 of Set 7 | paris
# Processing Record 28 of Set 7 | hanstholm
# Processing Record 29 of Set 7 | kaitangata
# Processing Record 30 of Set 7 | loding
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | letlhakane
# Processing Record 33 of Set 7 | neyshabur
# Processing Record 34 of Set 7 | olenegorsk
# Processing Record 35 of Set 7 | gizo
# Processing Record 36 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 7 | padang
# Processing Record 38 of Set 7 | ouango
# Processing Record 39 of Set 7 | itarema
# Processing Record 40 of Set 7 | rockport
# Processing Record 41 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 7 | mangrol
# Processing Record 43 of Set 7 | aberdeen
# Processing Record 44 of Set 7 | sawakin
# Processing Record 45 of Set 7 | pringsewu
# Processing Record 46 of Set 7 | matara
# Processing Record 47 of Set 7 | monterey
# Processing Record 48 of Set 7 | port macquarie
# Processing Record 49 of Set 7 | northam
# Processing Record 50 of Set 7 | burica
# City not found. Skipping...
# Processing Record 1 of Set 8 | le vauclin
# Processing Record 2 of Set 8 | sitka
# Processing Record 3 of Set 8 | zaysan
# Processing Record 4 of Set 8 | limon
# Processing Record 5 of Set 8 | leua
# Processing Record 6 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 7 of Set 8 | cabedelo
# Processing Record 8 of Set 8 | charters towers
# Processing Record 9 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 10 of Set 8 | chokwe
# Processing Record 11 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 12 of Set 8 | grafton
# Processing Record 13 of Set 8 | bushehr
# Processing Record 14 of Set 8 | cherskiy
# Processing Record 15 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 8 | kangavar
# Processing Record 17 of Set 8 | wilmington
# Processing Record 18 of Set 8 | balkanabat
# Processing Record 19 of Set 8 | norman wells
# Processing Record 20 of Set 8 | havre-saint-pierre
# Processing Record 21 of Set 8 | narsaq
# Processing Record 22 of Set 8 | barcelos
# Processing Record 23 of Set 8 | harwich
# Processing Record 24 of Set 8 | hasaki
# Processing Record 25 of Set 8 | bonavista
# Processing Record 26 of Set 8 | morondava
# Processing Record 27 of Set 8 | kieta
# Processing Record 28 of Set 8 | synya
# Processing Record 29 of Set 8 | olavarria
# Processing Record 30 of Set 8 | senmonorom
# City not found. Skipping...
# Processing Record 31 of Set 8 | uusikaupunki
# Processing Record 32 of Set 8 | manoel urbano
# Processing Record 33 of Set 8 | mildura
# Processing Record 34 of Set 8 | geraldton
# Processing Record 35 of Set 8 | ostrovnoy
# Processing Record 36 of Set 8 | sehithwa
# Processing Record 37 of Set 8 | baghdad
# Processing Record 38 of Set 8 | izvestkovyy
# Processing Record 39 of Set 8 | itacare
# Processing Record 40 of Set 8 | shaowu
# Processing Record 41 of Set 8 | huarmey
# Processing Record 42 of Set 8 | lompoc
# Processing Record 43 of Set 8 | anloga
# Processing Record 44 of Set 8 | moreira sales
# Processing Record 45 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 8 | saalfelden
# City not found. Skipping...
# Processing Record 47 of Set 8 | kuytun
# Processing Record 48 of Set 8 | omsukchan
# Processing Record 49 of Set 8 | karratha
# Processing Record 50 of Set 8 | marana
# Processing Record 1 of Set 9 | presque isle
# Processing Record 2 of Set 9 | santa isabel do rio negro
# Processing Record 3 of Set 9 | doka
# Processing Record 4 of Set 9 | qaqortoq
# Processing Record 5 of Set 9 | cervo
# Processing Record 6 of Set 9 | porto novo
# Processing Record 7 of Set 9 | swinoujscie
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | nichinan
# Processing Record 10 of Set 9 | soe
# Processing Record 11 of Set 9 | eyl
# Processing Record 12 of Set 9 | agadir
# Processing Record 13 of Set 9 | alta
# Processing Record 14 of Set 9 | mahajanga
# Processing Record 15 of Set 9 | osa
# Processing Record 16 of Set 9 | lundazi
# Processing Record 17 of Set 9 | sulangan
# Processing Record 18 of Set 9 | bethel
# Processing Record 19 of Set 9 | the valley
# Processing Record 20 of Set 9 | camacha
# Processing Record 21 of Set 9 | namatanai
# Processing Record 22 of Set 9 | qaracala
# Processing Record 23 of Set 9 | ugoofaaru
# Processing Record 24 of Set 9 | longyearbyen
# Processing Record 25 of Set 9 | alegrete
# Processing Record 26 of Set 9 | duluth
# Processing Record 27 of Set 9 | port hardy
# Processing Record 28 of Set 9 | ulaangom
# Processing Record 29 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 9 | berlevag
# Processing Record 31 of Set 9 | taoudenni
# Processing Record 32 of Set 9 | kabalo
# Processing Record 33 of Set 9 | marsh harbour
# Processing Record 34 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 9 | puerto colombia
# Processing Record 36 of Set 9 | diffa
# Processing Record 37 of Set 9 | haapiti
# Processing Record 38 of Set 9 | bonthe
# Processing Record 39 of Set 9 | pimenta bueno
# Processing Record 40 of Set 9 | ambulu
# Processing Record 41 of Set 9 | imbituba
# Processing Record 42 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 43 of Set 9 | okato
# Processing Record 44 of Set 9 | severobaykalsk
# Processing Record 45 of Set 9 | kumluca
# Processing Record 46 of Set 9 | bay roberts
# Processing Record 47 of Set 9 | teruel
# Processing Record 48 of Set 9 | partenit
# Processing Record 49 of Set 9 | french harbor
# Processing Record 50 of Set 9 | vanimo
# Processing Record 1 of Set 10 | limbe
# Processing Record 2 of Set 10 | edd
# Processing Record 3 of Set 10 | linxia
# Processing Record 4 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 10 | satuk
# Processing Record 7 of Set 10 | monster
# Processing Record 8 of Set 10 | piacabucu
# Processing Record 9 of Set 10 | guiberoua
# Processing Record 10 of Set 10 | smithers
# Processing Record 11 of Set 10 | samur
# Processing Record 12 of Set 10 | jutai
# Processing Record 13 of Set 10 | kharar
# Processing Record 14 of Set 10 | gunjur
# Processing Record 15 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 10 | le moule
# Processing Record 18 of Set 10 | manzanillo
# Processing Record 19 of Set 10 | oranjemund
# Processing Record 20 of Set 10 | taltal
# Processing Record 21 of Set 10 | bathsheba
# Processing Record 22 of Set 10 | derzhavinsk
# Processing Record 23 of Set 10 | porbandar
# Processing Record 24 of Set 10 | moustheni
# Processing Record 25 of Set 10 | nantucket
# Processing Record 26 of Set 10 | kuybysheve
# Processing Record 27 of Set 10 | paragominas
# Processing Record 28 of Set 10 | bhimunipatnam
# Processing Record 29 of Set 10 | bud
# Processing Record 30 of Set 10 | pingshan
# Processing Record 31 of Set 10 | sakakah
# Processing Record 32 of Set 10 | mbekenyera
# Processing Record 33 of Set 10 | faanui
# Processing Record 34 of Set 10 | xining
# Processing Record 35 of Set 10 | pecos
# Processing Record 36 of Set 10 | mangan
# Processing Record 37 of Set 10 | codrington
# Processing Record 38 of Set 10 | kavieng
# Processing Record 39 of Set 10 | dobrljin
# Processing Record 40 of Set 10 | xiaoyi
# Processing Record 41 of Set 10 | fereydun kenar
# Processing Record 42 of Set 10 | husavik
# Processing Record 43 of Set 10 | maniitsoq
# Processing Record 44 of Set 10 | diamantino
# Processing Record 45 of Set 10 | marang
# Processing Record 46 of Set 10 | solnechnyy
# Processing Record 47 of Set 10 | dunedin
# Processing Record 48 of Set 10 | nago
# Processing Record 49 of Set 10 | willowmore
# Processing Record 50 of Set 10 | kruisfontein
# Processing Record 1 of Set 11 | maridi
# Processing Record 2 of Set 11 | morant bay
# Processing Record 3 of Set 11 | lingao
# Processing Record 4 of Set 11 | nova venecia
# Processing Record 5 of Set 11 | sao filipe
# Processing Record 6 of Set 11 | taguatinga
# Processing Record 7 of Set 11 | saldanha
# Processing Record 8 of Set 11 | jalu
# Processing Record 9 of Set 11 | angoche
# Processing Record 10 of Set 11 | snasa
# Processing Record 11 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 12 of Set 11 | oum hadjer
# Processing Record 13 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 11 | yumen
# Processing Record 15 of Set 11 | mtinko
# Processing Record 16 of Set 11 | hammerfest
# Processing Record 17 of Set 11 | sooke
# Processing Record 18 of Set 11 | gemena
# Processing Record 19 of Set 11 | sisimiut
# Processing Record 20 of Set 11 | samana
# Processing Record 21 of Set 11 | bacolod
# Processing Record 22 of Set 11 | zapolyarnyy
# Processing Record 23 of Set 11 | dera ismail khan
# Processing Record 24 of Set 11 | sungairaya
# Processing Record 25 of Set 11 | miri
# Processing Record 26 of Set 11 | clyde river
# Processing Record 27 of Set 11 | presidencia roque saenz pena
# Processing Record 28 of Set 11 | hays
# Processing Record 29 of Set 11 | plouzane
# Processing Record 30 of Set 11 | olbia
# Processing Record 31 of Set 11 | salisbury
# Processing Record 32 of Set 11 | xihe
# Processing Record 33 of Set 11 | tautira
# Processing Record 34 of Set 11 | dromolaxia
# Processing Record 35 of Set 11 | ypsonas
# Processing Record 36 of Set 11 | torbat-e jam
# Processing Record 37 of Set 11 | moussoro
# Processing Record 38 of Set 11 | pierre
# Processing Record 39 of Set 11 | acarau
# Processing Record 40 of Set 11 | taywarah
# Processing Record 41 of Set 11 | nanzhang
# Processing Record 42 of Set 11 | severodvinsk
# Processing Record 43 of Set 11 | severo-yeniseyskiy
# Processing Record 44 of Set 11 | maceio
# Processing Record 45 of Set 11 | ponta delgada
# Processing Record 46 of Set 11 | manyana
# Processing Record 47 of Set 11 | yar-sale
# Processing Record 48 of Set 11 | kuvandyk
# Processing Record 49 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | udalguri
# Processing Record 1 of Set 12 | camocim
# Processing Record 2 of Set 12 | aykhal
# Processing Record 3 of Set 12 | hanchuan
# Processing Record 4 of Set 12 | abonnema
# Processing Record 5 of Set 12 | sterling
# Processing Record 6 of Set 12 | colares
# Processing Record 7 of Set 12 | sidi ali
# Processing Record 8 of Set 12 | mount isa
# Processing Record 9 of Set 12 | tigil
# Processing Record 10 of Set 12 | khatra
# Processing Record 11 of Set 12 | ust-maya
# Processing Record 12 of Set 12 | palaikastron
# Processing Record 13 of Set 12 | pasighat
# Processing Record 14 of Set 12 | cedar city
# Processing Record 15 of Set 12 | tambura
# Processing Record 16 of Set 12 | altamira
# Processing Record 17 of Set 12 | novorozhdestvenskaya
# Processing Record 18 of Set 12 | bagdarin
# Processing Record 19 of Set 12 | kloulklubed
# Processing Record 20 of Set 12 | morehead
# Processing Record 21 of Set 12 | port said
# Processing Record 22 of Set 12 | amahai
# Processing Record 23 of Set 12 | azare
# Processing Record 24 of Set 12 | bowen
# Processing Record 25 of Set 12 | puerto quijarro
# Processing Record 26 of Set 12 | inirida
# Processing Record 27 of Set 12 | mount darwin
# Processing Record 28 of Set 12 | canyon
# Processing Record 29 of Set 12 | tazovskiy
# Processing Record 30 of Set 12 | sinfra
# Processing Record 31 of Set 12 | peterhead
# Processing Record 32 of Set 12 | gat
# Processing Record 33 of Set 12 | pontal do parana
# Processing Record 34 of Set 12 | umm kaddadah
# Processing Record 35 of Set 12 | storforshei
# Processing Record 36 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 12 | marivan
# Processing Record 38 of Set 12 | atocha
# Processing Record 39 of Set 12 | gravelbourg
# Processing Record 40 of Set 12 | novobirilyussy
# Processing Record 41 of Set 12 | xinye
# Processing Record 42 of Set 12 | san marcos
# Processing Record 43 of Set 12 | port-cartier
# Processing Record 44 of Set 12 | topolobampo
# Processing Record 45 of Set 12 | sao felix do xingu
# Processing Record 46 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 12 | aspindza
# Processing Record 48 of Set 12 | san francisco
# Processing Record 49 of Set 12 | liwale
# Processing Record 50 of Set 12 | sembakung
# Processing Record 1 of Set 13 | tsiroanomandidy
# Processing Record 2 of Set 13 | araouane
# Processing Record 3 of Set 13 | moyale
# Processing Record 4 of Set 13 | beringovskiy
# Processing Record 5 of Set 13 | sorland
# Processing Record 6 of Set 13 | itainopolis
# Processing Record 7 of Set 13 | ondjiva
# Processing Record 8 of Set 13 | lucea
# Processing Record 9 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 10 of Set 13 | kalat
# Processing Record 11 of Set 13 | kirakira
# Processing Record 12 of Set 13 | prabumulih
# Processing Record 13 of Set 13 | stepnyak
# Processing Record 14 of Set 13 | harper
# Processing Record 15 of Set 13 | rognan
# Processing Record 16 of Set 13 | ouallam
# Processing Record 17 of Set 13 | sur
# Processing Record 18 of Set 13 | grand gaube
# Processing Record 19 of Set 13 | nexo
# Processing Record 20 of Set 13 | tuatapere
# Processing Record 21 of Set 13 | coahuayana
# Processing Record 22 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 23 of Set 13 | sao sepe
# Processing Record 24 of Set 13 | ati
# Processing Record 25 of Set 13 | ishigaki
# Processing Record 26 of Set 13 | tiarei
# Processing Record 27 of Set 13 | beloha
# Processing Record 28 of Set 13 | tucupita
# Processing Record 29 of Set 13 | sucua
# Processing Record 30 of Set 13 | penarroya-pueblonuevo
# Processing Record 31 of Set 13 | new plymouth
# Processing Record 32 of Set 13 | santa isabel
# Processing Record 33 of Set 13 | matay
# Processing Record 34 of Set 13 | kolimvari
# City not found. Skipping...
# Processing Record 35 of Set 13 | kalmunai
# Processing Record 36 of Set 13 | winona
# Processing Record 37 of Set 13 | chemal
# Processing Record 38 of Set 13 | umm lajj
# Processing Record 39 of Set 13 | olafsvik
# Processing Record 40 of Set 13 | kiunga
# Processing Record 41 of Set 13 | tura
# Processing Record 42 of Set 13 | kochubey
# Processing Record 43 of Set 13 | odweyne
# Processing Record 44 of Set 13 | san cristobal
# Processing Record 45 of Set 13 | bireun
# Processing Record 46 of Set 13 | kotra
# Processing Record 47 of Set 13 | rocha
# Processing Record 48 of Set 13 | flinders
# Processing Record 49 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 13 | te anau
# Processing Record 1 of Set 14 | houma
# Processing Record 2 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 3 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 14 | mogadouro
# Processing Record 5 of Set 14 | salalah
# Processing Record 6 of Set 14 | saint-francois
# Processing Record 7 of Set 14 | seminole
# Processing Record 8 of Set 14 | aquiraz
# Processing Record 9 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 14 | moerai
# Processing Record 11 of Set 14 | paiho
# City not found. Skipping...
# Processing Record 12 of Set 14 | banjarmasin
# Processing Record 13 of Set 14 | antalaha
# Processing Record 14 of Set 14 | marawi
# Processing Record 15 of Set 14 | smidovich
# Processing Record 16 of Set 14 | cordoba
# Processing Record 17 of Set 14 | nurota
# Processing Record 18 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 14 | auki
# Processing Record 20 of Set 14 | pacific grove
# Processing Record 21 of Set 14 | dieppe
# Processing Record 22 of Set 14 | churapcha
# Processing Record 23 of Set 14 | pawai
# Processing Record 24 of Set 14 | bubaque
# Processing Record 25 of Set 14 | labrea
# Processing Record 26 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 14 | honningsvag
# Processing Record 28 of Set 14 | chumphon
# Processing Record 29 of Set 14 | sinnamary
# Processing Record 30 of Set 14 | bardiyah
# Processing Record 31 of Set 14 | sturgeon falls
# Processing Record 32 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 33 of Set 14 | hay river
# Processing Record 34 of Set 14 | do gonbadan
# Processing Record 35 of Set 14 | cam ranh
# Processing Record 36 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 14 | tambovka
# Processing Record 38 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | touros
# Processing Record 40 of Set 14 | vestmanna
# Processing Record 41 of Set 14 | calvinia
# Processing Record 42 of Set 14 | batagay-alyta
# Processing Record 43 of Set 14 | carballo
# Processing Record 44 of Set 14 | belgorod
# Processing Record 45 of Set 14 | kismayo
# Processing Record 46 of Set 14 | bahraich
# Processing Record 47 of Set 14 | lata
# Processing Record 48 of Set 14 | madang
# Processing Record 49 of Set 14 | xingyi
# Processing Record 50 of Set 14 | maragogi
# Processing Record 1 of Set 15 | turukhansk
# Processing Record 2 of Set 15 | sistranda
# Processing Record 3 of Set 15 | manutuke
# Processing Record 4 of Set 15 | opuwo
# Processing Record 5 of Set 15 | ouargaye
# Processing Record 6 of Set 15 | marathon
# Processing Record 7 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 8 of Set 15 | richards bay
# Processing Record 9 of Set 15 | henties bay
# Processing Record 10 of Set 15 | molodizhne
# Processing Record 11 of Set 15 | nouadhibou
# Processing Record 12 of Set 15 | waingapu
# Processing Record 13 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 15 | monchegorsk
# Processing Record 15 of Set 15 | ontario
# Processing Record 16 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 15 | svetlyy
# Processing Record 18 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 15 | yamethin
# Processing Record 20 of Set 15 | angra
# City not found. Skipping...
# Processing Record 21 of Set 15 | bucerias
# Processing Record 22 of Set 15 | dushanbe
# Processing Record 23 of Set 15 | jiayuguan
# Processing Record 24 of Set 15 | mitsamiouli
# Processing Record 25 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 26 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 15 | high level
# Processing Record 28 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 15 | saint-augustin
# Processing Record 30 of Set 15 | sile
# Processing Record 31 of Set 15 | goderich
# Processing Record 32 of Set 15 | san policarpo
# Processing Record 33 of Set 15 | paola
# Processing Record 34 of Set 15 | bandarbeyla
# Processing Record 35 of Set 15 | sosnovo-ozerskoye
# Processing Record 36 of Set 15 | kurayoshi
# Processing Record 37 of Set 15 | mizdah
# Processing Record 38 of Set 15 | san antonio
# Processing Record 39 of Set 15 | posyet
# Processing Record 40 of Set 15 | langenzenn
# Processing Record 41 of Set 15 | aksarka
# Processing Record 42 of Set 15 | pangnirtung
# Processing Record 43 of Set 15 | zhaotong
# Processing Record 44 of Set 15 | umea
# Processing Record 45 of Set 15 | bilibino
# Processing Record 46 of Set 15 | eydhafushi
# Processing Record 47 of Set 15 | awjilah
# Processing Record 48 of Set 15 | hervey bay
# Processing Record 49 of Set 15 | uvaly
# Processing Record 50 of Set 15 | kudahuvadhoo
# Processing Record 1 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 16 | gashua
# Processing Record 3 of Set 16 | boralday
# Processing Record 4 of Set 16 | zanatepec
# City not found. Skipping...
# Processing Record 5 of Set 16 | silver city
# Processing Record 6 of Set 16 | bokovskaya
# Processing Record 7 of Set 16 | opochka
# Processing Record 8 of Set 16 | arkhangelskoye
# Processing Record 9 of Set 16 | baykit
# Processing Record 10 of Set 16 | sirjan
# Processing Record 11 of Set 16 | fangshan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Cape Town      ZA -33.9258   18.4232     46.11        79           0
# 1  Lavrentiya      RU  65.5833 -171.0000     43.45        81         100
# 2     Rikitea      PF -23.1203 -134.9692     73.76        73           1
# 3   Vermilion      US  40.1667  -87.7506     79.39        88          40
# 4        Lasa      IT  46.6166   10.7002     65.28        85           0
# 5     Kolaras      IN  25.2333   77.6000     76.23        90         100
# 6     Paamiut      GL  61.9940  -49.6678     42.01        93         100
# 7      Dikson      RU  73.5069   80.5464     38.35        95          99
# 8       Adrar      MR  20.5022  -10.0711     86.65        16           7
# 9    Tasiilaq      GL  65.6145  -37.6368     42.96        97         100
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1        2.33     overcast clouds
# 2       19.73          light rain
# 3        4.61    scattered clouds
# 4        3.36           clear sky
# 5        4.03     overcast clouds
# 6        2.64     overcast clouds
# 7       18.21     overcast clouds
# 8        8.99           clear sky
# 9        2.53     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
